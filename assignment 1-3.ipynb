# %% [markdown]
# Print the number of rows and the number of columns in the dataset.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ad = pd.read_csv('adult.data', sep = ',\s', engine='python', header = None, names = ['age', 'workclass', 'fnlwgt', 'education', 'num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'])
data = pd.DataFrame(ad)
print(data)
# Out:
#        age         workclass  fnlwgt   education  num      marital-status  \
# 0       39         State-gov   77516   Bachelors   13       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors   13  Married-civ-spouse
# 2       38           Private  215646     HS-grad    9            Divorced
# 3       53           Private  234721        11th    7  Married-civ-spouse
# 4       28           Private  338409   Bachelors   13  Married-civ-spouse
# ...    ...               ...     ...         ...  ...                 ...
# 32556   27           Private  257302  Assoc-acdm   12  Married-civ-spouse
# 32557   40           Private  154374     HS-grad    9  Married-civ-spouse
# 32558   58           Private  151910     HS-grad    9             Widowed
# 32559   22           Private  201490     HS-grad    9       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad    9  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# ...

# %%
index = ad.index
numRows = len(index)
print(numRows)
# Out:
# 32561

# %% [markdown]
# Show the rows at row index 1000 till 1010 (i.e., 11 rows).

# %%
print(data.iloc[1000:1010])
# Out:
#       age         workclass  fnlwgt     education  num      marital-status  \
# 1000   20           Private  148294  Some-college   10       Never-married
# 1001   50           Private  168212     Doctorate   16  Married-civ-spouse
# 1002   38         State-gov  343642       HS-grad    9  Married-civ-spouse
# 1003   23         Local-gov  115244     Bachelors   13       Never-married
# 1004   31           Private  162572       HS-grad    9       Never-married
# 1005   58           Private  356067     Bachelors   13  Married-civ-spouse
# 1006   66           Private  271567       HS-grad    9           Separated
# 1007   39      Self-emp-inc  180804       HS-grad    9  Married-civ-spouse
# 1008   54  Self-emp-not-inc  123011       HS-grad    9  Married-civ-spouse
# 1009   26           Private  109186  Some-college   10  Married-civ-spouse
#
#              occupation   relationship   race     sex  capital-gain  \
# 1000      Other-service      Own-child  White    Male             0
# ...

# %% [markdown]
# For each of categorical columns, show the unique values in the column and the frequency of each value.

# %%
#ad.age.unique()
ad.describe()
# Out:
#                 age        fnlwgt           num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# Show the subset that age is less than 20 and income is >50K.

# %%
ad[(ad['age'] < 20 ) & (ad['income'] == ">50K")]
# Out:
#        age workclass  fnlwgt education  num      marital-status  \
# 7741    19   Private  323605   7th-8th    4       Never-married
# 22910   19         ?  200790      12th    8  Married-civ-spouse
#
#           occupation    relationship   race     sex  capital-gain  \
# 7741   Other-service   Not-in-family  White    Male             0
# 22910              ?  Other-relative  White  Female         15024
#
#        capital-loss  hours-per-week native-country income
# 7741              0              60  United-States   >50K
# 22910             0              40  United-States   >50K

# %%
#ynrSubset = pd.Dataframe(ad, columns = 'age', 'income')
#ad[(ad['age'] < 20 ) & (ad['income'] == ">50K")]
subset = ad[(ad['income'] == ">50K")]
subset['income'].describe()
# Out:
# count     7841
# unique       1
# top       >50K
# freq      7841
# Name: income, dtype: object

# %%
ad[(ad['income']) == "<=50K"]
# Out:
#        age         workclass  fnlwgt     education  num      marital-status  \
# 0       39         State-gov   77516     Bachelors   13       Never-married
# 1       50  Self-emp-not-inc   83311     Bachelors   13  Married-civ-spouse
# 2       38           Private  215646       HS-grad    9            Divorced
# 3       53           Private  234721          11th    7  Married-civ-spouse
# 4       28           Private  338409     Bachelors   13  Married-civ-spouse
# ...    ...               ...     ...           ...  ...                 ...
# 32553   32           Private  116138       Masters   14       Never-married
# 32555   22           Private  310152  Some-college   10       Never-married
# 32556   27           Private  257302    Assoc-acdm   12  Married-civ-spouse
# 32558   58           Private  151910       HS-grad    9             Widowed
# 32559   22           Private  201490       HS-grad    9       Never-married
#
# ...

# %% [markdown]
# Get a subset that age is between 39 and 42 and hours-per-week is 40.

# %%
subset = ad[(ad['age'] > 38) & (ad['age'] < 43) & (ad['hours-per-week'] == 40)]
subset
# Out:
#        age    workclass  fnlwgt   education  num      marital-status  \
# 0       39    State-gov   77516   Bachelors   13       Never-married
# 9       42      Private  159449   Bachelors   13  Married-civ-spouse
# 14      40      Private  121772   Assoc-voc   11  Married-civ-spouse
# 48      41    State-gov  101603   Assoc-voc   11  Married-civ-spouse
# 76      40      Private   32214  Assoc-acdm   12  Married-civ-spouse
# ...    ...          ...     ...         ...  ...                 ...
# 32399   42      Private  161510   Bachelors   13  Married-civ-spouse
# 32428   39  Federal-gov  110622   Bachelors   13  Married-civ-spouse
# 32473   41  Federal-gov  160467     Masters   14            Divorced
# 32480   41      Private  201495     Masters   14  Married-civ-spouse
# 32557   40      Private  154374     HS-grad    9  Married-civ-spouse
#
#               occupation   relationship                race     sex  \
# 0           Adm-clerical  Not-in-family               White    Male
# ...

# %% [markdown]
# Create a scatter plot between the column capital-gain and the income column.

# %%
ad.plot(kind='scatter', x='capital-gain', y='income', title='Plot between income and capital gain')
# Out:
# <AxesSubplot:title={'center':'Plot between income and capital gain'}, xlabel='capital-gain', ylabel='income'>

# %% [markdown]
# Get a subset including only five columns: age, education, sex, hours-per-week and income level, and only for the people with the education level as Masters or Prof-school or Doctorate. Then show the first 5 rows and last 5 rows of this subset.

# %%
subset = ad[['age', 'education', 'sex', 'hours-per-week', 'income']]
filteredSubset = subset[(ad['education'] == 'Masters') | (ad['education'] == 'Prof-school') | (ad['education'] == "Doctorate")]
filteredSubset.head(5)
# Out:
#     age  education     sex  hours-per-week income
# 5    37    Masters  Female              40  <=50K
# 8    31    Masters  Female              50   >50K
# 19   43    Masters  Female              45   >50K
# 20   40  Doctorate    Male              60   >50K
# 47   44    Masters  Female              40  <=50K

# %%
filteredSubset.tail(5)
# Out:
#        age    education     sex  hours-per-week income
# 32539   71    Doctorate    Male              10   >50K
# 32544   31      Masters  Female              30  <=50K
# 32548   65  Prof-school    Male              60  <=50K
# 32553   32      Masters    Male              11  <=50K
# 32554   53      Masters    Male              40   >50K

# %% [markdown]
# Print the respective statistical information of the age column for those with income >50K and those with income <=50K. Describe a brief comparison between the two-set information using the markdown cell in your notebook.

# %%
moneySet = ad[['income']]
richSubset = moneySet[(moneySet['income'] == ">50K")]
poorSubset = moneySet[(moneySet['income'] == "<=50K")]
richSubset.describe()
# Out:
#        income
# count    7841
# unique      1
# top      >50K
# freq     7841

# %%
poorSubset.describe()
# Out:
#        income
# count   24720
# unique      1
# top     <=50K
# freq    24720

# %% [markdown]
# In this exercise the set of people who have an income of more than 50K are in the richSubset. The set of people who have an income of less than 50K are in the poorSubset. Currently the poorSubset has 24,720 members while the rich subset has 7,841 members.

# %% [markdown]
# Plot a respective histogram for the column hours-per-week for those with income <=50K and for those with income >50K. Describe a brief comparison between the two histograms using the markdown cell in your notebook.

# %%
subset = ad[(ad['hours-per-week']) & (ad['income'] == '>50K')]
#subset
subset1 = ad[(ad['hours-per-week']) & (ad['income'] == '<=50K')]
#subset1

subset['hours-per-week'].plot(kind='hist', title='>50K');

# %%
subset1['hours-per-week'].plot(kind='hist', title='<=50K');

# %% [markdown]
# In this exercise the set of people who have an income of more than 50K are in the subset. The set of people who have an income of less than 50K are in the subset1. The histogram shows that the members in subset1 are more diverse concerning the hours they work per week seeing how its between 15 to 60 hours per week. On the other hand, people in subset mostly work between 30 to 60 hours per week.

# %% [markdown]
# Get a subset that all have the same income level >50K and this subset must have at least 15 rows (You can specify conditions using multiple columns except for the income column).

# %%
subset = ad[(ad['education'] =='Masters') & (ad['age'] >20) & (ad['income'] == '>50K')]
subset
# Out:
#        age         workclass  fnlwgt education  num      marital-status  \
# 8       31           Private   45781   Masters   14       Never-married
# 19      43  Self-emp-not-inc  292175   Masters   14            Divorced
# 100     76           Private  124191   Masters   14  Married-civ-spouse
# 135     38       Federal-gov  125933   Masters   14  Married-civ-spouse
# 164     45  Self-emp-not-inc  201080   Masters   14  Married-civ-spouse
# ...    ...               ...     ...       ...  ...                 ...
# 32457   33           Private  139057   Masters   14  Married-civ-spouse
# 32480   41           Private  201495   Masters   14  Married-civ-spouse
# 32504   50           Private  208630   Masters   14            Divorced
# 32513   46           Private   42972   Masters   14  Married-civ-spouse
# 32554   53           Private  321865   Masters   14  Married-civ-spouse
#
#             occupation   relationship                race     sex  \
# ...

# %% [markdown]
# Get a subset that all have the same income level <=50K and this subset must have at least 15 rows (You can specify conditions using multiple columns except for the income column).

# %%
subset = ad[(ad['age'] < 30) & (ad['hours-per-week'] < 40) & (ad['income'] == '<=50K')]
subset
# Out:
#        age         workclass  fnlwgt     education  num      marital-status  \
# 12      23           Private  122272     Bachelors   13       Never-married
# 16      25  Self-emp-not-inc  176756       HS-grad    9       Never-married
# 34      22         State-gov  311512  Some-college   10  Married-civ-spouse
# 37      19           Private  544091       HS-grad    9   Married-AF-spouse
# 44      25           Private  289980       HS-grad    9       Never-married
# ...    ...               ...     ...           ...  ...                 ...
# 32524   26           Private  191648    Assoc-acdm   12       Never-married
# 32529   29           Private  125976       HS-grad    9           Separated
# 32535   22           Private  325033          12th    8       Never-married
# 32556   27           Private  257302    Assoc-acdm   12  Married-civ-spouse
# 32559   22           Private  201490       HS-grad    9       Never-married
#
# ...
